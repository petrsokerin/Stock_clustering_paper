# %%
from datetime import datetime
from datetime import timedelta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import os
import json
from tqdm.notebook import tqdm
import plotly.express as px
import plotly

from comet_ml import Experiment

# %%
with open('../config/config.json', 'r') as file:
    config = json.load(file)
    
with open('../config/config_emb_path.json', 'r') as file:
    config_emb = json.load(file)
    
rs = config['random_state']

# %%
def change_features(df):
    df['AVG_returns'] = (df['AVG_returns'] + 1) ** 252 - 1
    df['Risk'] = (df['Risk'] + 1) ** np.sqrt(252) - 1
    df['Alpha'] = df['Alpha'].round(4)
    df['Drawdown'] = -df['Drawdown']
    

    return df

# %% [markdown]
# # Building table

# %%
year_start = 2020
fine_tune = False

# %%
def filter_risk_return(df, filter_baselines=['sp500', 'sectors'], save_methods=['sectors', 'sp500']):      
        
    for baseline in filter_baselines:

        risk_baseline = df[df.emb_model == baseline]['Risk'].values[0]
        mask_risk = df['Risk'] <= risk_baseline
        mask = mask_risk

        return_baseline = df[df.emb_model == baseline]['AVG_returns'].values[0]
        mask_return = df['AVG_returns'] >= return_baseline
        mask = mask & mask_return
        
        drd_baseline = df[df.emb_model == baseline]['Drawdown'].values[0]
        mask_drd = df['Drawdown'] <= drd_baseline
        mask = mask & mask_drd
        
        mask_save = df['emb_model'].isin(save_methods)
        mask = mask | mask_save

        df = df[mask]
        
    mask_save = df['emb_model'].isin(save_methods)
    df = df[(df['AVG_returns'] > 0) | mask_save]
    return df.sort_values('Sharpe', ascending=False)

# %%
config['financial_metric_path'].format(year_start, fine_tune)
# Out:
# 'results/financial_metric_2020_False_december_.csv'

# %%
financial_metrics = {year_start:pd.read_csv('../'+config['financial_metric_path'].format(year_start, fine_tune), index_col=0) 
                     for year_start in [2020, 2021]}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0abf2d47fe2d> in <module>
# ----> 1 financial_metrics = {year_start:pd.read_csv('../'+config['financial_metric_path'].format(year_start, fine_tune), index_col=0)
#       2                      for year_start in [2020, 2021]}
#
# <ipython-input-7-0abf2d47fe2d> in <dictcomp>(.0)
# ----> 1 financial_metrics = {year_start:pd.read_csv('../'+config['financial_metric_path'].format(year_start, fine_tune), index_col=0)
#       2                      for year_start in [2020, 2021]}
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/financial_metric_2021_False_december_.csv'

# %%
df_2020 = pd.read_csv('../'+config['financial_metric_path'].format(2020, False), index_col=0)
# df_2020_tuned = pd.read_csv('../'+config['financial_metric_path'].format(2020, True), index_col=0)
# df_2021 = pd.read_csv('../'+config['financial_metric_path'].format(2021, False), index_col=0)

df_2020 = change_features(df_2020)
# df_2020_tuned = change_features(df_2020_tuned)
# df_2021 = change_features(df_2021)

print(df_2020.shape)
df_2020.head()
# Out:
# (40, 10)
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.453507  0.437050  0.554507  0.0012  0.059204 -0.038122  44.948793
# port     0.483981  0.468114  0.515221  0.0013  0.059237 -0.040397  45.108995
# port     0.293635  0.307741  0.780590  0.0007  0.053087 -0.028124  37.728144
# port     0.353085  0.310419  0.779779  0.0009  0.063074 -0.028341  39.016213
# port     0.326064  0.334986  0.733832  0.0008  0.054621 -0.030305  33.676552
#
#       Recovery clust_model        emb_model
# port     202.0      KMeans           ts2vec
# port     190.0         Agg           ts2vec
# port     142.0      KMeans      PersImage_2
# port     144.0         Agg      PersImage_2
# port     201.0      KMeans  PersLandscape_1

# %%
df_2020_filtered = filter_risk_return(df_2020, filter_baselines=['sectors'], 
                                      save_methods=['sectors', 'sp500'])
df_2020_filtered.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-4a3738878f9d> in <module>
# ----> 1 df_2020_filtered = filter_risk_return(df_2020, filter_baselines=['sectors'],
#       2                                       save_methods=['sectors', 'sp500'])
#       3 df_2020_filtered.head()
#
# <ipython-input-21-ddc672f04c00> in filter_risk_return(df, filter_baselines, save_methods)
#       3     for baseline in filter_baselines:
#       4
# ----> 5         risk_baseline = df[df.emb_model == baseline]['Risk'].values[0]
#       6         mask_risk = df['Risk'] <= risk_baseline
#       7         mask = mask_risk
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df_2020['emb_model'].unique()
# Out:
# array(['ts2vec', 'PersImage_2', 'PersLandscape_1',
#        'transformer_embds_sum_23', 'transformer_embds3',
#        'transformer_embds2', 'table_finance_features', 'autoencoder_mlp',
#        'PersLandscape_2', 'tsfresh', 'pca', 'topo_features',
#        'autoencoder_conv', 'umap', 'fastica', 'transformer_embds1',
#        'autoencoder_lstm', 'transformer_embds_sum_all', 'tnse',
#        'PersImage_1'], dtype=object)

# %%
dict_category2emb = {
    'topological' : [
        'PersImage_2',
        'PersLandscape_1'
        'PersImage_1',
        'PersLandscape_2',
        'topo_features'                 
      ],
    
    'dim_reduction' : ['umap', 'pca', 'fastica', 'tnse'],
    
    'transformers' : [ 'transformer_embds1',
 'transformer_embds2',
 'transformer_embds3',
 'transformer_embds_sum_23',
 'transformer_embds_sum_all',],
    
    'autoencoders' : [ 'autoencoder_conv',
 'autoencoder_lstm',
 'autoencoder_mlp',],
    
    'baselines' : ['sp500', 'sectors'],
    
    'interpretable' : [ 'tsfresh', 'table_finance_features'],
    
    'time_clustering' : ['KShape',
 'MSTcorr',
 'TimeSeriesKMeans'],
    
    'time_embedding' : ['ts2vec', 'signal2vec_embds']
}

# %%
dict_emb2cat = {method:categ for categ, list_methods in dict_category2emb.items() for method in list_methods }
#dict_emb2cat

# %%
df_2020 = pd.read_csv('../' + 'results/financial_metric_{}_{}_{}.csv'.format(2020, False, 'december_'), index_col=0)
df_2020 = change_features(df_2020)

df_to_rebuild = df_2020

df_2020_clusters = pd.read_csv('../'+config['clust_metric_path'].format(2020, False), index_col=0)
df_to_rebuild = pd.merge(df_2020_clusters.drop(columns=['clust_model']), df_to_rebuild, on='emb_model', how='outer')

df_best_clustering = df_to_rebuild.sort_values(['Risk'], ascending=False)
df_best_clustering = df_best_clustering.groupby('emb_model', as_index=False, sort=True).first()
df_best_clustering['category'] = df_best_clustering['emb_model'].map(dict_emb2cat)
df_best_clustering.drop(columns=['Beta', 'Alpha', 'VaR']).to_csv('../results/table_all_methods_december_.csv')
df_best_clustering.sort_values('Risk')
# Out:
#                     emb_model        DB          HC       Sil       hom  \
# 0                 PersImage_1  2.160083   38.085767  0.111894  0.091855
# 1                 PersImage_2  2.107882   51.174200  0.087259  0.087995
# 9      table_finance_features  1.121949  115.549853  0.194085  0.154215
# 15   transformer_embds_sum_23  1.134028  184.085481  0.321149  0.043921
# 14         transformer_embds3  1.202013  176.910613  0.312100  0.038040
# 10                       tnse  0.985253  127.193142  0.230976  0.298667
# 11              topo_features  1.546094  101.950124  0.134255  0.131627
# 13         transformer_embds2  2.758432   24.476381  0.058524  0.101400
# 2             PersLandscape_1  1.918107   39.956934  0.070351  0.108945
# 3             PersLandscape_2  2.279878   22.778592  0.033095  0.062482
# 19                       umap  0.874204  561.365885  0.420302  0.533727
# 8                         pca  1.832162    4.598209 -0.086476  0.145809
# 6             autoencoder_mlp  2.935187   35.777333  0.037273  0.244774
# 5            autoencoder_lstm  1.057146  228.240410  0.237722  0.131777
# 7                     fastica  3.239758    3.942405  0.017239  0.181541
# 12         transformer_embds1  1.358071  155.434048  0.274814  0.048210
# 4            autoencoder_conv  2.315668   24.231063  0.040197  0.215463
# 16  transformer_embds_sum_all  2.578133   13.606852  0.007649  0.391448
# 17                     ts2vec  2.024043   80.150906  0.079267  0.153958
# 18                    tsfresh  2.125778   48.460830  0.088954  0.332047
#
#     AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# 0      0.097029  0.281114  0.811275  0.0000  0.015911 -0.025951  31.648254
# 1      0.353085  0.310419  0.779779  0.0009  0.063074 -0.028341  39.016213
# 9      0.168078  0.326285  0.750731  0.0003  0.027825 -0.029613  38.889481
# 15     0.404346  0.359416  0.674966  0.0011  0.063034 -0.032226  31.763108
# 14     0.381981  0.362079  0.655524  0.0010  0.059386 -0.032433  37.899521
# 10     0.263784  0.379746  0.697887  0.0006  0.039646 -0.033800  41.695679
# 11     0.323281  0.380808  0.686822  0.0008  0.048450 -0.033881  34.497910
# 13     0.457257  0.381613  0.641843  0.0012  0.066989 -0.033943  36.272470
# 2      0.411442  0.406893  0.642528  0.0011  0.057555 -0.035868  34.575551
# 3      0.530376  0.413514  0.640465  0.0014  0.071354 -0.036367  34.431483
# 19     0.283818  0.415502  0.600470  0.0007  0.039520 -0.036516  48.501389
# 8      0.193629  0.415673  0.568955  0.0004  0.026439 -0.036529  44.606808
# 6      0.352351  0.416924  0.565669  0.0009  0.048713 -0.036622  46.854405
# 5      0.403527  0.419988  0.598392  0.0011  0.055018 -0.036852  40.248260
# 7      0.118617  0.421010  0.561989  0.0002  0.014638 -0.036928  41.077921
# 12     0.479382  0.425914  0.593859  0.0013  0.063619 -0.037295  35.459948
# 4      0.298660  0.428455  0.594793  0.0008  0.040509 -0.037484  50.264277
# 16     0.140749  0.464610  0.553011  0.0003  0.016663 -0.040143  49.378998
# 17     0.483981  0.468114  0.515221  0.0013  0.059237 -0.040397  45.108995
# 18     0.305749  0.517872  0.438587  0.0008  0.035361 -0.043950  65.573585
#
#     Recovery clust_model        category
# 0      210.0         Agg             NaN
# 1      144.0         Agg     topological
# 9      201.0         Agg   interpretable
# 15     143.0         Agg    transformers
# 14     129.0      KMeans    transformers
# 10     174.0         Agg   dim_reduction
# 11     203.0      KMeans     topological
# 13     129.0         Agg    transformers
# 2      203.0         Agg             NaN
# 3      205.0      KMeans     topological
# 19     215.0         Agg   dim_reduction
# 8      240.0         Agg   dim_reduction
# 6      238.0         Agg    autoencoders
# 5      142.0      KMeans    autoencoders
# 7      397.0      KMeans   dim_reduction
# 12     142.0      KMeans    transformers
# 4      233.0      KMeans    autoencoders
# 16     229.0         Agg    transformers
# 17     190.0         Agg  time_embedding
# 18     205.0         Agg   interpretable

# %%
df_2020 = pd.read_csv('../' + 'results/financial_metric_{}_{}_{}.csv'.format(2020, False, 'may'), index_col=0)
df_2020 = change_features(df_2020)

df_to_rebuild = df_2020

df_2020_clusters = pd.read_csv('../'+config['clust_metric_path'].format(2020, False), index_col=0)
df_to_rebuild = pd.merge(df_2020_clusters.drop(columns=['clust_model']), df_to_rebuild, on='emb_model', how='outer')

df_best_clustering = df_to_rebuild.sort_values(['Risk'], ascending=False)
df_best_clustering = df_best_clustering.groupby('emb_model', as_index=False, sort=True).first()
df_best_clustering['category'] = df_best_clustering['emb_model'].map(dict_emb2cat)
df_best_clustering.drop(columns=['Beta', 'Alpha', 'VaR']).to_csv('../results/table_all_methods_december_.csv')
df_best_clustering.sort_values('Risk')
# Out:
#                     emb_model        DB          HC       Sil       hom  \
# 2                 PersImage_1  2.160083   38.085767  0.111894  0.091855
# 13                      sp500       NaN         NaN       NaN       NaN
# 3                 PersImage_2  2.107882   51.174200  0.087259  0.087995
# 14     table_finance_features  1.121949  115.549853  0.194085  0.154215
# 0                      KShape       NaN         NaN       NaN       NaN
# 18         transformer_embds2  2.666001   23.045589  0.040220  0.138601
# 12                    sectors       NaN         NaN       NaN       NaN
# 20   transformer_embds_sum_23  1.134028  184.085481  0.321149  0.043921
# 6            TimeSeriesKMeans       NaN         NaN       NaN       NaN
# 16              topo_features  1.546094  101.950124  0.134255  0.131627
# 19         transformer_embds3  1.198022  173.640291  0.305755  0.041086
# 24                       umap  0.874204  561.365885  0.420302  0.533727
# 17         transformer_embds1  1.371570  155.709577  0.268678  0.047718
# 15                       tnse  0.985253  127.193142  0.230976  0.298667
# 4             PersLandscape_1  2.054301   36.666365  0.051789  0.106513
# 10                    fastica  1.866907    4.621920 -0.058815  0.153344
# 22                     ts2vec  1.987504   84.010727  0.083092  0.163971
# 5             PersLandscape_2  2.279878   22.778592  0.033095  0.062482
# 9             autoencoder_mlp  2.935187   35.777333  0.037273  0.244774
# 11                        pca  3.199042    3.935593 -0.009795  0.126640
# 8            autoencoder_lstm  0.930905  260.249710  0.298711  0.136290
# 7            autoencoder_conv  2.315668   24.231063  0.040197  0.215463
# 1                     MSTcorr       NaN         NaN       NaN       NaN
# 23                    tsfresh  2.125778   48.460830  0.088954  0.332047
# 21  transformer_embds_sum_all  2.998859   14.005781  0.031237  0.348786
#
#     AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# 2      0.122132  0.257027  0.838556  0.0001  0.023430 -0.023948  28.280809
# 13     0.098372  0.289888  1.000000  0.0000  0.015781 -0.026672  33.924960
# 3      0.306826  0.291371  0.801863  0.0007  0.058206 -0.026793  37.563553
# 14     0.221930  0.338905  0.731522  0.0005  0.036560 -0.030616  42.134962
# 0      0.256991  0.340169  0.763000  0.0006  0.042477 -0.030716  34.778614
# 18     0.399068  0.341030  0.713682  0.0010  0.065185 -0.030784  32.533257
# 12     0.311464  0.348002  0.687612  0.0008  0.050514 -0.031333  41.943386
# 20     0.470947  0.362660  0.698392  0.0012  0.071898 -0.032479  32.269475
# 6      0.202942  0.362845  0.714069  0.0004  0.031290 -0.032493  35.403761
# 16     0.327747  0.374868  0.696038  0.0008  0.049773 -0.033424  35.052341
# 19     0.434153  0.376100  0.651415  0.0011  0.064711 -0.033519  37.311554
# 24     0.351519  0.400323  0.614586  0.0009  0.050323 -0.035371  46.650009
# 17     0.460632  0.401139  0.632777  0.0012  0.064602 -0.035433  38.261348
# 15     0.400759  0.405505  0.605466  0.0011  0.056331 -0.035763  46.145227
# 4      0.439404  0.418809  0.607703  0.0012  0.059651 -0.036764  42.581463
# 10     0.109766  0.419269  0.575138  0.0001  0.013276 -0.036798  45.835787
# 22     0.326317  0.422293  0.585941  0.0009  0.044743 -0.037024  44.791335
# 5      0.541027  0.423015  0.603117  0.0014  0.071211 -0.037078  28.971757
# 9      0.327319  0.425091  0.588373  0.0009  0.044625 -0.037233  44.836381
# 11     0.180003  0.425582  0.553267  0.0004  0.023895 -0.037270  45.289962
# 8      0.483632  0.429083  0.583669  0.0013  0.063720 -0.037531  40.248260
# 7      0.257895  0.432163  0.581805  0.0006  0.034678 -0.037759  49.992122
# 1      0.427295  0.433849  0.596819  0.0011  0.056424 -0.037885  41.964669
# 23     0.191779  0.456849  0.526800  0.0004  0.024145 -0.039577  57.999457
# 21     0.128433  0.473514  0.540717  0.0002  0.014656 -0.040788  50.403205
#
#     Recovery       clust_model         category
# 2      195.0            KMeans              NaN
# 13     200.0             sp500        baselines
# 3       69.0               Agg      topological
# 14     195.0               Agg    interpretable
# 0      211.0            KShape  time_clustering
# 18     143.0            KMeans     transformers
# 12     219.0           sectors        baselines
# 20     143.0            KMeans     transformers
# 6      366.0  TimeSeriesKMeans  time_clustering
# 16     201.0            KMeans      topological
# 19     143.0            KMeans     transformers
# 24     222.0            KMeans    dim_reduction
# 17     201.0            KMeans     transformers
# 15     129.0            KMeans    dim_reduction
# 4      203.0            KMeans              NaN
# 10     240.0               Agg    dim_reduction
# 22     188.0               Agg   time_embedding
# 5       80.0               Agg      topological
# 9      143.0            KMeans     autoencoders
# 11     295.0               Agg    dim_reduction
# 8      143.0            KMeans     autoencoders
# 7      234.0            KMeans     autoencoders
# 1       90.0           MSTcorr  time_clustering
# 23     240.0               Agg    interpretable
# 21     229.0               Agg     transformers

# %%
df_2020
# Out:
#           DB           HC       Sil       hom       clust_model  \
# 0   1.987504    84.010727  0.083092  0.163971            KMeans
# 0   2.024043    80.150906  0.079267  0.153958               Agg
# 0   1.954198    54.617123  0.123347  0.093071            KMeans
# 0   2.107882    51.174200  0.087259  0.087995               Agg
# 0   1.918107    39.956934  0.070351  0.108945            KMeans
# 0   2.054301    36.666365  0.051789  0.106513               Agg
# 0   1.157965   188.370477  0.321772  0.045826            KMeans
# 0   1.134028   184.085481  0.321149  0.043921               Agg
# 0   1.202013   176.910613  0.312100  0.038040            KMeans
# 0   1.198022   173.640291  0.305755  0.041086               Agg
# 0   2.758432    24.476381  0.058524  0.101400            KMeans
# 0   2.666001    23.045589  0.040220  0.138601               Agg
# 0   1.121949   115.549853  0.194085  0.154215            KMeans
# 0   1.229258   101.090507  0.161998  0.147194               Agg
# 0   2.935187    35.777333  0.037273  0.244774            KMeans
# 0   2.762847    33.926177  0.020054  0.268479               Agg
# 0   2.279878    22.778592  0.033095  0.062482            KMeans
# 0   2.574524    19.807779  0.012141  0.066708               Agg
# 0   2.125778    48.460830  0.088954  0.332047            KMeans
# 0   2.097995    45.595049  0.082275  0.348642               Agg
# 0   3.199042     3.935593 -0.009795  0.126640            KMeans
# 0   1.832162     4.598209 -0.086476  0.145809               Agg
# 0   1.546094   101.950124  0.134255  0.131627            KMeans
# 0   1.540826    94.074812  0.142804  0.125270               Agg
# 0   2.074320    28.867834  0.059238  0.238712            KMeans
# 0   2.315668    24.231063  0.040197  0.215463               Agg
# 0   0.874204   561.365885  0.420302  0.533727            KMeans
# 0   0.849512   505.022282  0.391153  0.559763               Agg
# 0   3.239758     3.942405  0.017239  0.181541            KMeans
# 0   1.866907     4.621920 -0.058815  0.153344               Agg
# 0   1.358071   155.434048  0.274814  0.048210            KMeans
# 0   1.371570   155.709577  0.268678  0.047718               Agg
# 0   0.930905   260.249710  0.298711  0.136290            KMeans
# 0   1.057146   228.240410  0.237722  0.131777               Agg
# 0   2.998859    14.005781  0.031237  0.348786            KMeans
# 0   2.578133    13.606852  0.007649  0.391448               Agg
# 0   0.985253   127.193142  0.230976  0.298667            KMeans
# 0   1.120879   103.230834  0.155554  0.263226               Agg
# 0   2.160083    38.085767  0.111894  0.091855            KMeans
# 0   2.095456    35.299947  0.047298  0.090432               Agg
# 0  20.950594     1.294891 -0.324762  0.060256           MSTcorr
# 0  11.608563     1.135959 -0.299911  0.054698            KShape
# 0   0.611243  3402.281224  0.405630  0.033781  TimeSeriesKMeans
# 0   3.644767    10.869699 -0.008997  1.000000           sectors
#
#                    emb_model
# 0                     ts2vec
# 0                     ts2vec
# 0                PersImage_2
# 0                PersImage_2
# 0            PersLandscape_1
# 0            PersLandscape_1
# 0   transformer_embds_sum_23
# 0   transformer_embds_sum_23
# 0         transformer_embds3
# 0         transformer_embds3
# 0         transformer_embds2
# 0         transformer_embds2
# 0     table_finance_features
# 0     table_finance_features
# 0            autoencoder_mlp
# 0            autoencoder_mlp
# 0            PersLandscape_2
# 0            PersLandscape_2
# 0                    tsfresh
# 0                    tsfresh
# 0                        pca
# 0                        pca
# 0              topo_features
# 0              topo_features
# 0           autoencoder_conv
# 0           autoencoder_conv
# 0                       umap
# 0                       umap
# 0                    fastica
# 0                    fastica
# 0         transformer_embds1
# 0         transformer_embds1
# 0           autoencoder_lstm
# 0           autoencoder_lstm
# 0  transformer_embds_sum_all
# 0  transformer_embds_sum_all
# 0                       tnse
# 0                       tnse
# 0                PersImage_1
# 0                PersImage_1
# 0                    MSTcorr
# 0                     KShape
# 0           TimeSeriesKMeans
# 0                    sectors

# %%
df_best_clustering = pd.read_csv('table_all_methods_old.csv')
df_best_clustering.sort_values('Risk')
# Out:
#     Unnamed: 0                      emb_model        DB          HC       Sil  \
# 10          10                          sp500       NaN         NaN       NaN
# 36          36                           umap  1.173824   24.756191 -0.243332
# 17          17  takens_mult_PI_2_sigma=0.0005  0.350201    8.322796  0.321104
# 23          23   takens_one_PI_0_sigma=0.0005  2.343354   57.314122  0.079197
# 20          20                takens_one_BC_0  1.206720  219.953984  0.243884
# 25          25   takens_one_PI_2_sigma=0.0005  0.467841    6.003348  0.262037
# 15          15  takens_mult_PI_0_sigma=0.0005  0.423499   14.309940  0.377641
# 24          24   takens_one_PI_1_sigma=0.0005  0.319803   10.388697  0.432609
# 14          14               takens_mult_BC_2  0.457607   10.709994  0.240211
# 1            1                        MSTcorr  3.731503    0.081506 -0.751448
# 16          16  takens_mult_PI_1_sigma=0.0005  0.311177    9.058265  0.470917
# 27          27                takens_one_PL_2  0.311802   10.268861  0.379736
# 29          29             transformer_embds1  1.340904  152.907053  0.276434
# 22          22                takens_one_BC_2  0.453790    6.411142  0.273747
# 32          32       transformer_embds_sum_23  1.142738  130.819923  0.216855
# 13          13               takens_mult_BC_1  0.501752    4.927500  0.222172
# 3            3               autoencoder_conv  2.091430   24.328769  0.046438
# 28          28                           tnse  1.054698  124.121011  0.230666
# 9            9               signal2vec_embds  1.357437  230.563619  0.181192
# 31          31             transformer_embds3  1.202075  129.118784  0.223701
# 0            0                         KShape  7.429789    3.861956 -0.362652
# 19          19               takens_mult_PL_2  0.380150    8.073443  0.324279
# 12          12               takens_mult_BC_0  1.288452  169.081388  0.206201
# 21          21                takens_one_BC_1  2.272078   31.873566  0.062859
# 7            7                            pca  4.163205    3.138456 -0.081676
# 6            6                        fastica  4.163205    3.138456 -0.081676
# 8            8                        sectors  3.744944   10.966541 -0.013596
# 33          33      transformer_embds_sum_all  2.379674   12.205344  0.050083
# 4            4               autoencoder_lstm  0.887779  298.791626  0.279768
# 2            2               TimeSeriesKMeans  1.272514  524.973125  0.250456
# 30          30             transformer_embds2  2.866121   21.733386  0.049527
# 34          34                         ts2vec  1.819899   85.714328  0.107950
# 5            5                autoencoder_mlp  0.348737    8.551307  0.425324
# 11          11         table_finance_features  1.143082  123.411532  0.197825
# 35          35                        tsfresh  0.462938    5.830445  0.201398
# 18          18               takens_mult_PL_1  2.132998   30.654586  0.063087
# 26          26                takens_one_PL_1  0.434641    5.298668  0.268090
#
#          hom  AVG_returns      Risk    Sharpe   Drawdown  Recovery  \
# 10       NaN     0.068939  0.288985  0.009137  33.924960     179.0
# 36  0.223404     0.208990  0.314975  0.036560  37.997495     133.0
# 17  0.027223     0.508435  0.319754  0.085943  32.473692      55.0
# 23  0.131069     0.269434  0.320425  0.046981  36.170465      81.0
# 20  0.084446     0.213173  0.322478  0.036582  35.774649     121.0
# 25  0.025424     0.394508  0.324655  0.067334  32.822206      82.0
# 15  0.028869     0.102995  0.327738  0.015084  43.476745     219.0
# 24  0.027312     0.393651  0.333660  0.065602  37.237865     100.0
# 14  0.027779     0.340816  0.339595  0.056336  36.801444      76.0
# 1   0.024262     0.037729  0.341597  0.001588  49.249316     239.0
# 16  0.029398     0.016286  0.354625 -0.002756  47.480629     492.0
# 27  0.023011     0.606091  0.355021  0.091323  24.775282      57.0
# 29  0.050180     0.352284  0.355779  0.055841  38.912704      70.0
# 22  0.028900     0.404731  0.356168  0.063590  35.514546     115.0
# 32  0.051649     0.330917  0.359422  0.052108  36.297709     180.0
# 13  0.030582     0.350680  0.362683  0.054676  40.247957     132.0
# 3   0.259177     0.275020  0.365467  0.042758  40.449770     135.0
# 28  0.374750     0.190368  0.367808  0.028829  46.286768     214.0
# 9   0.169571     0.031469  0.372371  0.000281  49.544986     257.0
# 31  0.054524     0.420422  0.372577  0.063342  31.765110     180.0
# 0   0.035396     0.335218  0.372948  0.051100  33.954587      93.0
# 19  0.028428     0.261016  0.375108  0.039640  39.231977     180.0
# 12  0.080154     0.418929  0.376816  0.062520  34.045320      72.0
# 21  0.063728     0.464832  0.377153  0.068685  33.899962      82.0
# 7   0.240306     0.230659  0.378232  0.034615  33.534508     317.0
# 6   0.240306     0.230659  0.378232  0.034615  33.534508     317.0
# 8   1.000000     0.345204  0.385629  0.051072  42.313929     185.0
# 33  0.332102     0.138769  0.387676  0.019110  42.962064     206.0
# 4   0.160054     0.108661  0.401834  0.013583  47.793661     207.0
# 2   0.070370     0.209302  0.407082  0.029297  47.218338     209.0
# 30  0.126102     0.356413  0.411002  0.049856  41.246102     288.0
# 34  0.150108     0.495915  0.411040  0.067593  43.955665      75.0
# 5   0.023234     0.287371  0.413770  0.040159  37.470175     119.0
# 11  0.204439     0.165177  0.430370  0.021467  43.611548     148.0
# 35  0.024445     0.281739  0.430928  0.038029  41.064541     317.0
# 18  0.080639     0.077526  0.439310  0.007715  49.992064     179.0
# 26  0.024985     0.254840  0.447228  0.033275  41.850209     154.0
#
#          clust_model         category
# 10             sp500        baselines
# 36            KMeans    dim_reduction
# 17            KMeans      topological
# 23            KMeans      topological
# 20            KMeans      topological
# 25            KMeans      topological
# 15               Agg      topological
# 24            KMeans      topological
# 14            KMeans      topological
# 1            MSTcorr  time_clustering
# 16               Agg      topological
# 27            KMeans      topological
# 29            KMeans     transformers
# 22            KMeans      topological
# 32               Agg     transformers
# 13            KMeans      topological
# 3             KMeans     autoencoders
# 28            KMeans    dim_reduction
# 9                Agg   time_embedding
# 31            KMeans     transformers
# 0             KShape  time_clustering
# 19               Agg      topological
# 12            KMeans      topological
# 21            KMeans      topological
# 7                Agg    dim_reduction
# 6                Agg    dim_reduction
# 8            sectors        baselines
# 33            KMeans     transformers
# 4                Agg     autoencoders
# 2   TimeSeriesKMeans  time_clustering
# 30               Agg     transformers
# 34            KMeans   time_embedding
# 5             KMeans     autoencoders
# 11               Agg    interpretable
# 35               Agg    interpretable
# 18               Agg      topological
# 26               Agg      topological

# %%
df_best_clustering.sort_values('Risk')
# Out:
#                     emb_model        DB          HC       Sil       hom  \
# 0                 PersImage_1  2.160083   38.085767  0.111894  0.091855
# 1                 PersImage_2  2.107882   51.174200  0.087259  0.087995
# 9      table_finance_features  1.121949  115.549853  0.194085  0.154215
# 15   transformer_embds_sum_23  1.134028  184.085481  0.321149  0.043921
# 14         transformer_embds3  1.202013  176.910613  0.312100  0.038040
# 10                       tnse  0.985253  127.193142  0.230976  0.298667
# 11              topo_features  1.546094  101.950124  0.134255  0.131627
# 13         transformer_embds2  2.758432   24.476381  0.058524  0.101400
# 2             PersLandscape_1  1.918107   39.956934  0.070351  0.108945
# 3             PersLandscape_2  2.279878   22.778592  0.033095  0.062482
# 19                       umap  0.874204  561.365885  0.420302  0.533727
# 8                         pca  1.832162    4.598209 -0.086476  0.145809
# 6             autoencoder_mlp  2.935187   35.777333  0.037273  0.244774
# 5            autoencoder_lstm  1.057146  228.240410  0.237722  0.131777
# 7                     fastica  3.239758    3.942405  0.017239  0.181541
# 12         transformer_embds1  1.358071  155.434048  0.274814  0.048210
# 4            autoencoder_conv  2.315668   24.231063  0.040197  0.215463
# 16  transformer_embds_sum_all  2.578133   13.606852  0.007649  0.391448
# 17                     ts2vec  2.024043   80.150906  0.079267  0.153958
# 18                    tsfresh  2.125778   48.460830  0.088954  0.332047
#
#     AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# 0      0.097029  0.281114  0.811275  0.0000  0.015911 -0.025951  31.648254
# 1      0.353085  0.310419  0.779779  0.0009  0.063074 -0.028341  39.016213
# 9      0.168078  0.326285  0.750731  0.0003  0.027825 -0.029613  38.889481
# 15     0.404346  0.359416  0.674966  0.0011  0.063034 -0.032226  31.763108
# 14     0.381981  0.362079  0.655524  0.0010  0.059386 -0.032433  37.899521
# 10     0.263784  0.379746  0.697887  0.0006  0.039646 -0.033800  41.695679
# 11     0.323281  0.380808  0.686822  0.0008  0.048450 -0.033881  34.497910
# 13     0.457257  0.381613  0.641843  0.0012  0.066989 -0.033943  36.272470
# 2      0.411442  0.406893  0.642528  0.0011  0.057555 -0.035868  34.575551
# 3      0.530376  0.413514  0.640465  0.0014  0.071354 -0.036367  34.431483
# 19     0.283818  0.415502  0.600470  0.0007  0.039520 -0.036516  48.501389
# 8      0.193629  0.415673  0.568955  0.0004  0.026439 -0.036529  44.606808
# 6      0.352351  0.416924  0.565669  0.0009  0.048713 -0.036622  46.854405
# 5      0.403527  0.419988  0.598392  0.0011  0.055018 -0.036852  40.248260
# 7      0.118617  0.421010  0.561989  0.0002  0.014638 -0.036928  41.077921
# 12     0.479382  0.425914  0.593859  0.0013  0.063619 -0.037295  35.459948
# 4      0.298660  0.428455  0.594793  0.0008  0.040509 -0.037484  50.264277
# 16     0.140749  0.464610  0.553011  0.0003  0.016663 -0.040143  49.378998
# 17     0.483981  0.468114  0.515221  0.0013  0.059237 -0.040397  45.108995
# 18     0.305749  0.517872  0.438587  0.0008  0.035361 -0.043950  65.573585
#
#     Recovery clust_model        category
# 0      210.0         Agg             NaN
# 1      144.0         Agg     topological
# 9      201.0         Agg   interpretable
# 15     143.0         Agg    transformers
# 14     129.0      KMeans    transformers
# 10     174.0         Agg   dim_reduction
# 11     203.0      KMeans     topological
# 13     129.0         Agg    transformers
# 2      203.0         Agg             NaN
# 3      205.0      KMeans     topological
# 19     215.0         Agg   dim_reduction
# 8      240.0         Agg   dim_reduction
# 6      238.0         Agg    autoencoders
# 5      142.0      KMeans    autoencoders
# 7      397.0      KMeans   dim_reduction
# 12     142.0      KMeans    transformers
# 4      233.0      KMeans    autoencoders
# 16     229.0         Agg    transformers
# 17     190.0         Agg  time_embedding
# 18     205.0         Agg   interpretable

# %% [markdown]
# ## COMET_ML

# %%
year_start = 2020
fine_tune = True

for key in config_emb.keys():
    config_emb[key] = config_emb[key].format(year_start)

# %%
df_finance = pd.read_csv('../'+config['financial_metric_path'].format(year_start, fine_tune), index_col=0)
df_clust = pd.read_csv('../'+config['clust_metric_path'].format(year_start, fine_tune), index_col=0)

df_finance = change_features(df_finance)

# %%
df_finance.head()
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.495915  0.411040  0.601512  0.0014  0.067593 -0.036180  43.955665
# port     0.191167  0.363129  0.640662  0.0005  0.029286 -0.032515  36.463147
# port     0.404731  0.356168  0.696695  0.0011  0.063590 -0.031973  35.514546
# port    -0.065147  0.247098  0.941967 -0.0005 -0.027456 -0.023112  31.130780
# port     0.606091  0.355021  0.674516  0.0017  0.091323 -0.031883  24.775282
#
#       Recovery clust_model        emb_model
# port      75.0      KMeans           ts2vec
# port     154.0         Agg           ts2vec
# port     115.0      KMeans  takens_one_BC_2
# port     642.0         Agg  takens_one_BC_2
# port      57.0      KMeans  takens_one_PL_2

# %%
model_del = 'Agg' if model_name == 'KMeans' else 'KMeans'

df_finance = df_finance[df_finance.clust_model != model_del]
df_clust = df_clust[df_clust.clust_model != model_del]

df_finance = df_finance.set_index('emb_model').drop(columns=['clust_model'])
df_clust = df_clust.set_index('emb_model').drop(columns=['clust_model'])

df_data = df_finance.join(df_clust)

assert len(df_data) == len(df_clust) + 1 == len(df_finance)
df_data.head()
# Out:
#                           AVG_returns      Risk      Beta   Alpha    Sharpe  \
# emb_model
# ts2vec                       0.191167  0.363129  0.640662  0.0005  0.029286
# takens_one_BC_2             -0.065147  0.247098  0.941967 -0.0005 -0.027456
# takens_one_PL_2              0.156138  0.317826  0.740148  0.0003  0.026150
# transformer_embds_sum_23     0.330917  0.359422  0.667278  0.0009  0.052108
# transformer_embds3           0.350557  0.343130  0.696339  0.0010  0.057361
#
#                                VaR   Drawdown  Recovery        DB          HC  \
# emb_model
# ts2vec                   -0.032515  36.463147     154.0  0.320173   18.543424
# takens_one_BC_2          -0.023112  31.130780     642.0  0.453790    6.411142
# takens_one_PL_2          -0.028937  28.214303     182.0  0.311802   10.268861
# transformer_embds_sum_23 -0.032227  36.297709     180.0  1.142738  130.819923
# transformer_embds3       -0.030949  34.166709     180.0  1.202075  129.118784
#
#                                Sil       hom
# emb_model
# ts2vec                    0.516730  0.028243
# takens_one_BC_2           0.273747  0.028900
# takens_one_PL_2           0.379736  0.023011
# transformer_embds_sum_23  0.216855  0.051649
# transformer_embds3        0.223701  0.054524

# %%
# for model_name, data in tqdm(df_model.iterrows()):
    
#     experiment = Experiment(
#     api_key="W4Exl5JlKMoVHRelfS04Tc0Lg",
#     project_name="stock-clustering-with-time-series-embeddings",
#     workspace="petrsokerin",
#     )

#     experiment.set_name(model_name)

#     hyper_params = {
#         "model": model_name,
#         "include_2020": year_start == 2021,
#         "fine_tune": fine_tune,
#     }

#     experiment.log_parameters(hyper_params)
    
#     print(model_name)
#     metrics = data.to_dict()
#     experiment.log_metrics(metrics)
